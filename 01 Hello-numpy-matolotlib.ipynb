# %% [markdown]
# # 🌍 AI World – Python & NumPy Basics
# Welcome to my first notebook in VS Code.
# This notebook covers basic Python, arrays, math, and plotting.

# %%
print("Hello AI World! 🚀 This is ShahZad starting his journey.")
# Out:
# Hello AI World! 🚀 This is ShahZad starting his journey.

# %%
import numpy as np
data=np.array([4, 5, 6, 7, 8])
print('original_data:',data)
print('squared', data**2)
print('mean:', np.mean(data))
# Out:
# original_data: [4 5 6 7 8]
# squared [16 25 36 49 64]
# mean: 6.0

# %%
import matplotlib.pyplot as plt
plt.plot(data, data** 2,marker='o',color='purple')
plt.title('my first plot')
plt.xlabel('values')
plt.ylabel('square')
plt.grid(True)
plt.show()

# %% [markdown]
# #Summary
# in this notebook, i:
# -ran basic python
# - 📊 NumPy array operations
# - 📈 Plotting data with Matplotlib
# -launching my ai learning journey
# # I am excited to learn AI and contribute to the community!
# print ("Thank you for joining me on this journey! Let's make AI magic together! ✨")
